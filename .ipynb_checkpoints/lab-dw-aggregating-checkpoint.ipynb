# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %%
import pandas as pd
import requests
import json



def value_renaming_manuel(row):
    if str(row).strip().title() == "yes".strip().title():
        return "yes"
  
    
    else:
        return None

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by first performing data cleaning, formatting, and structuring.

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %%
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv"
df = pd.read_csv(url)
print(df.shape)
df.head(3)
dfnew = df.copy()
# Out:
# (10910, 26)

# %%
dfnew["Response"] = df["Response"].apply(value_renaming_manuel)
dfnew.dropna(subset = "Response", inplace = True)

print(df.shape)
print(dfnew.shape)
# Out:
# (10910, 26)
# (1466, 26)

# %%
dfnew["Response"].unique()
# Out:
# array(['yes'], dtype=object)

# %%
dfnew
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 3               3  XL78013      Oregon             22332.439460      yes
# 8               8  FM55990  California              5989.773931      yes
# 15             15  CW49887  California              4626.801093      yes
# 19             19  NJ54277  California              3746.751625      yes
# 27             27  MQ68407      Oregon              4376.363592      yes
# ...           ...      ...         ...                      ...      ...
# 10844       10844  FM31768     Arizona              5979.724161      yes
# 10852       10852  KZ80424  Washington              8382.478392      yes
# 10872       10872  XT67997  California              5979.724161      yes
# 10887       10887  BY78730      Oregon              8879.790017      yes
# 10897       10897  MM70762     Arizona              9075.768214      yes
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %%
dfnew = dfnew[dfnew["Total Claim Amount"]>=1000]
dfnew.reset_index()
# Out:
#     index  Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0     189         189  OK31456  California             11009.130490      yes
# 1     236         236  YJ16163      Oregon             11009.130490      yes
# 2     419         419  GW43195      Oregon             25807.063000      yes
# 3     442         442  IP94270     Arizona             13736.132500      yes
# 4     587         587  FJ28407  California              5619.689084      yes
# ..    ...         ...      ...         ...                      ...      ...
# 62  10351       10351  FN44127      Oregon              3508.569533      yes
# 63  10373       10373  XZ64172      Oregon             10963.957230      yes
# 64  10487       10487  IX60941      Oregon              3508.569533      yes
# 65  10565       10565  QO62792      Oregon              7840.165778      yes
# 66  10708       10708  CK39096      Oregon              5619.689084      yes
#
# ...

# %% [markdown]
# 2. Using the original Dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %%
df.head(5)
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
dfyes = df[df["Response"] == "Yes".strip()]
dfyes
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 3               3  XL78013      Oregon             22332.439460      Yes
# 8               8  FM55990  California              5989.773931      Yes
# 15             15  CW49887  California              4626.801093      Yes
# 19             19  NJ54277  California              3746.751625      Yes
# 27             27  MQ68407      Oregon              4376.363592      Yes
# ...           ...      ...         ...                      ...      ...
# 10844       10844  FM31768     Arizona              5979.724161      Yes
# 10852       10852  KZ80424  Washington              8382.478392      Yes
# 10872       10872  XT67997  California              5979.724161      Yes
# 10887       10887  BY78730      Oregon              8879.790017      Yes
# 10897       10897  MM70762     Arizona              9075.768214      Yes
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %%
dfyes.groupby(["Policy Type", "Gender"]).agg({"Total Claim Amount": "mean"})
# Out:
#                        Total Claim Amount
# Policy Type    Gender
# Corporate Auto F               433.738499
#                M               408.582459
# Personal Auto  F               452.965929
#                M               457.010178
# Special Auto   F               453.280164
#                M               429.527942

# %% [markdown]
# # Conclusions
#
# 1. on average for all three policy types, female customers have a higher total claim amount then male customers
# 2. on average for all personal autos, male customers have a higher total claim amoun than female customers
# 3. of all three policy types, personal auto has the highest mean of total claim amount

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
##not clear if for the original dataframe or the new dataframe

# %%
#new dataframe (only customers who responded with "yes")

dfstates = dfyes.groupby(["State"]).agg({"State": "count"})
dfstates
# Out:
#             State
# State
# Arizona       281
# California    504
# Nevada        140
# Oregon        419
# Washington    122

# %%
df500 = dfstates[dfstates["State"] >= 500]
df500
# Out:
#             State
# State
# California    504

# %%
#original dataframe (everything is above 500)
dfstates_2 = df.groupby(["State"]).agg({"State": "count"})
dfstates_2
# Out:
#             State
# State
# Arizona      1937
# California   3552
# Nevada        993
# Oregon       2909
# Washington    888

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
dfmedian = df.groupby(["Education", "Gender"]).agg({"Customer Lifetime Value": "median"})
dfmax = df.groupby(["Education", "Gender"]).agg({"Customer Lifetime Value": "max"})
dfmin = df.groupby(["Education", "Gender"]).agg({"Customer Lifetime Value": "min"})

display(dfmedian)
display(dfmax)
display(dfmin)
# Out:
#                              Customer Lifetime Value
# Education            Gender
# Bachelor             F                   5640.505303
#                      M                   5548.031892
# College              F                   5623.611187
#                      M                   6005.847375
# Doctor               F                   5332.462694
#                      M                   5577.669457
# High School or Below F                   6039.553187
#                      M                   6286.731006
# Master               F                   5729.855012
#                      M                   5579.099207
#                              Customer Lifetime Value
# Education            Gender
# Bachelor             F                   73225.95652
#                      M                   67907.27050
# College              F                   61850.18803
#                      M                   61134.68307
# Doctor               F                   44856.11397
# ...

# %% [markdown]
# ## Bonus

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month. Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %% [markdown]
# 6.  Display a new DataFrame that contains the number of policies sold by month, by state, for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
# your code goes here
